# %% [markdown]
# # Test of loading a stack

# %% [markdown]
# ## Test to see if ProcessEmbryo works

# %%
import ProcessEmbryo

# %%
test_stack, test_raw, test meta = process_stack("230212_stack6")
# Out:
#   Input In [2]
#     test_stack, test_raw, test meta = process_stack("230212_stack6")
#                                     ^
# SyntaxError: invalid syntax
