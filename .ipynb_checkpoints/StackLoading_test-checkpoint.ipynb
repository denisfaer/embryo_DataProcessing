# %% [markdown]
# # ProcessEmbryo test notebook

# %% [markdown]
# ## Testing ProcessEmbryo library import

# %% [markdown]
# Following the <code>pip install .</code> in the README, check that your kernel recognizes the library (note that you have to restart Jupyter the kernel was updated):

# %%
import ProcessEmbryo
print(ProcessEmbryo.__version__)
# Out:
# 25.04.22

# %% [markdown]
# If the above message is a date like "year.month.day" - the package was successfully installed. <br>
# This is also an indicator of the relevance of the version you're using, which can explain compatibility issues if too out of date. To update the package, simply download the latest version of the github folder, navigate into it with anaconda prompt and run <code>pip install .</code> - this should update everything automatically.

# %% [markdown]
# ## Testing stack loading

# %% [markdown]
# Import the functions that load and process a given stack's extraction files:

# %%
from ProcessEmbryo.load_stack import frame_IDs, lineage_reconstruct, find_cells, lineage_express, lineage_transform, prune_stack, process_stack

# %% [markdown]
# Run the stack-processing function on a sample stack: <br>
# (This should be generating messaged like "Processing 230212_stack6" and "Processing 230212_stack6 lineage 1 / 104")

# %%
# change stack path accordingly after downloading the folder (make sure to use '/')
stack_path = r'C:/Users/denis/Desktop/GitSpace/embryo_DataProcessing/datasets/Nanog_Gata6/230212_stack6'
processed_stack = process_stack(stack_path)
# Out:
# Processing 230212_stack6
#
# Loading the lineage tree graph:
# Lineage tree graph loaded successfully
#
# Loading channel extractions:
# Histone loaded
# Channel_1 loaded
# Channel_2 loaded
#
# Reconstructing cell lineages:
# Processing 230212_stack6 lineage 1 / 104
# Processing 230212_stack6 lineage 2 / 104
# Processing 230212_stack6 lineage 3 / 104
# Processing 230212_stack6 lineage 4 / 104
# Processing 230212_stack6 lineage 5 / 104
# Processing 230212_stack6 lineage 6 / 104
# Processing 230212_stack6 lineage 7 / 104
# Processing 230212_stack6 lineage 8 / 104
# Processing 230212_stack6 lineage 9 / 104
# Processing 230212_stack6 lineage 10 / 104
# Processing 230212_stack6 lineage 11 / 104
# Processing 230212_stack6 lineage 12 / 104
# Processing 230212_stack6 lineage 13 / 104
# WARNING: Lineage root cell identified as [231_90]
# Processing 230212_stack6 lineage 14 / 104
# Processing 230212_stack6 lineage 15 / 104
# Processing 230212_stack6 lineage 16 / 104
# ...

# %% [markdown]
# Testing extracted data is formatted correctly, should be [Frame, ID]

# %%
print(processed_stack[0][0][0])
# Out:
# [240, 732]

# %% [markdown]
# Testing extracted data is formatted correctly, should be [Frame, ID, CentX, CentY, CentZ, Histone, Nanog, Gata6]:

# %%
print(processed_stack[0][0][1][0])
# Out:
# [24, 9, 739.610104861773, 1040.01584842707, 22.2971877979028, 228.089370829361, 119.789252144977, 127.296050262612]
